# %%
# !pip install openai requests pillow
# Out:
# Requirement already satisfied: openai in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (2.32.0)
# Requirement already satisfied: requests in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (2.28.1)
# Requirement already satisfied: pillow in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (12.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from openai) (2.13.3)
# Requirement already satisfied: sniffio in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from requests) (1.26.13)
# Requirement already satisfied: colorama in c:\users\julia\appdata\local\programs\python\python310\lib\site-packages (from tqdm>4->openai) (0.4.6)
# WARNING: Ignoring invalid distribution -umpy (c:\users\julia\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\julia\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\julia\appdata\local\programs\python\python310\lib\site-packages)

# %%
import openai, requests, base64, os, json, time
print(f"openai: {openai.__version__}")
print("Imports OK")
# Out:
# openai: 2.32.0
# Imports OK

# %% [markdown]
# # NeurIPS Computational Resources & Reproducibility Metadata
#
# Required by **NeurIPS 2025 Paper Checklist §8**. Run to print a live hardware/version summary. Fill `[TODO]` fields before submission.

# %%
"""
NeurIPS 2025 Checklist S8 - Computational Resources
====================================================
Hardware
  GPU      : NVIDIA RTX A6000 (48 GB VRAM)
  CPU      : [TODO: e.g. AMD EPYC 7542 32-core]
  RAM      : [TODO: e.g. 256 GB DDR4]
  OS       : Windows 11 / Ubuntu 22.04
  Provider : Local on-premise workstation

Model & Inference
  Model      : gpt-5.5
  max_completion_tokens : 4096 per call
  Temp       : 0.0 (Zero-Shot / Sequential / LtM / ReAct / CoT)
               0.1 (Iterative)
               0.1-0.5 (Self-Consistency runs)
               0.1/0.7 (Meta-Prompting: analysis/generation)

API Calls per Video  (C = ceil(frames / 10))
  Zero-Shot        : C
  Sequential       : 5*C + 1
  Least-To-Most    : 8*C + 1
  ReAct            : C + 1
  True Iterative   : up to 8*C
  Self-Consistency : 5*C + 1
  Meta-Prompting   : 2*C + 2
  Chain-of-Thought : C + 1
  Total/video (50 frames, C=5) ~ 162 calls ~ 243 000 tokens

Total Compute (fill before submission)
  Dataset  : [TODO] videos x [TODO] avg frames
  Calls    : [TODO] x 162 = [TODO]
  Tokens   : [TODO] x 243 000 = [TODO]
  Time     : ~[TODO] hours

Reproducibility
  - Checkpoint files save progress after every video (atomic write)
  - Re-running any cell after failure resumes with zero extra API cost
  - All raw API responses saved as JSON before post-processing
  - Chunk-level saves after every 10-frame batch
"""
import subprocess, platform, datetime
print("=" * 64)
print(f"  NeurIPS Compute Summary  - {datetime.datetime.now().strftime('%Y-%m-%d %H:%M')}")
print("=" * 64)
print(f"  Python  : {platform.python_version()}")
print(f"  OS      : {platform.platform()}")
try:
    smi = subprocess.check_output(
        ["nvidia-smi", "--query-gpu=name,memory.total", "--format=csv,noheader"],
        text=True).strip()
    for line in smi.split("\n"):
        print(f"  GPU     : {line.strip()}")
except Exception:
    print("  GPU     : nvidia-smi not available")
try:
    import openai
    print(f"  openai  : {openai.__version__}")
except Exception:
    pass
print(f"  Model   : gpt-5.5")
print(f"  Chunks  : 10 frames/chunk  |  max_completion_tokens : 4096")
print(f"  Retry   : 7 attempts, exponential back-off, cap 5 min")
print("=" * 64)
# Out:
# ================================================================
#   NeurIPS Compute Summary  - 2026-04-28 21:00
# ================================================================
#   Python  : 3.10.11
#   OS      : Windows-10-10.0.26100-SP0
#   GPU     : NVIDIA H100 NVL, 95830 MiB
#   GPU     : NVIDIA H100 NVL, 95830 MiB
#   GPU     : NVIDIA H100 NVL, 95830 MiB
#   GPU     : NVIDIA H100 NVL, 95830 MiB
#   openai  : 2.32.0
#   Model   : gpt-5.5
#   Chunks  : 10 frames/chunk  |  max_completion_tokens : 4096
#   Retry   : 7 attempts, exponential back-off, cap 5 min
# ================================================================

# %% [markdown]
# #Least-To-Most Prompting
# 2. Least-To-Most Prompting Implementation
# Key Features:
#
# Processes all frames in chunks of 10 frames each
# Uses a sequence of 8 prompts with increasing complexity:
#
# - Simple object identification (low complexity)
# - People identification (low complexity)
# - Location/setting description (low complexity)
# - Basic action identification (low complexity)
# - Interaction analysis (medium complexity)
# - Unusual behavior detection (medium complexity)
# - Criminal activity analysis (high complexity)
# - Comprehensive timeline (high complexity)
#
#
# Includes a final comprehensive assessment that integrates all analyses
#
# Implementation Highlights:
#
# - Each step clearly labeled with its complexity level (Low, Medium, High)
# - Builds from simple identification tasks to complex analysis
# - Each chunk gets analyzed separately, with results combined before the next step
# - Previous observation steps provide context for later analytical steps

# %%
import os
import json
import base64
import requests
import time
from datetime import datetime
from collections import defaultdict


import threading
from concurrent.futures import ThreadPoolExecutor, as_completed
# ================================================================
#  CONFIGURATION  -  edit these paths to match your machine
# ================================================================
FRAMES_DIR     = r"C:\Opeyemi\PROMPTS\FRAMES"   # pre-extracted frames
RESULTS_BASE   = r"C:\Opeyemi\PROMPTS\RESULTS"  # all JSON outputs
FRAME_EXT      = ".jpg"
FRAME_INTERVAL = 1   # 1=every frame; 2=every other; etc.
BATCH_SIZE     = 20   # max frames per API call
MAX_WORKERS    = 4    # parallel videos processed at once (OpenAI rate limits depend on tier; raise carefully)

# ================================================================
#  FRAME HELPERS  -  self-contained in every cell
# ================================================================

def extract_frame_number(filename):
    """Return integer index from frame_00042.jpg style names."""
    import re as _re
    name = os.path.splitext(filename)[0]
    m = _re.search(r"frame[_\-]?(\d+)", name, _re.IGNORECASE)
    if m:
        return int(m.group(1))
    nums = _re.findall(r"\d+", name)
    return int(nums[-1]) if nums else 0


def discover_all_videos_and_frames(frames_dir=None):
    """
    Walk FRAMES_DIR and return a manifest of all extracted videos.

    Expected layout (created by the Video-to-Frames extractor):
        FRAMES_DIR/
            Abuse/
                Abuse001_x264/
                    frame_00001.jpg
                    frame_00002.jpg ...
                Abuse002_x264/ ...
            Arrest/ ...   (13 UCF-Crime categories)

    Returns dict "<CrimeType>_<VideoStem>" -> {
        "crime_type": "Abuse",
        "video_id":   "Abuse001_x264",
        "frames_dir": r"C:\...\FRAMES\Abuse\Abuse001_x264",
        "frames":     ["frame_00001.jpg", ...]   # sorted by number
    }
    """
    if frames_dir is None:
        frames_dir = FRAMES_DIR
    print(f"\n=== DISCOVERING FRAMES ===")
    print(f"    Root : {frames_dir}")
    all_videos = {}
    if not os.path.isdir(frames_dir):
        print(f"  ERROR: FRAMES_DIR not found: {frames_dir}")
        print("  Run the Video-to-Frames extractor first, or check the path.")
        return all_videos
    crime_types = sorted([
        d for d in os.listdir(frames_dir)
        if os.path.isdir(os.path.join(frames_dir, d)) and not d.startswith("_")
    ])
    print(f"  Categories : {crime_types}")
    for crime_type in crime_types:
        cat_dir = os.path.join(frames_dir, crime_type)
        video_stems = sorted([
            d for d in os.listdir(cat_dir)
            if os.path.isdir(os.path.join(cat_dir, d))
        ])
        print(f"    {crime_type:20s}: {len(video_stems)} videos")
        for video_stem in video_stems:
            vdir = os.path.join(cat_dir, video_stem)
            frame_files = sorted(
                [ff for ff in os.listdir(vdir) if ff.lower().endswith(FRAME_EXT)],
                key=extract_frame_number
            )
            if not frame_files:
                print(f"      WARNING: no {FRAME_EXT} frames in {vdir} - skipping")
                continue
            key = f"{crime_type}_{video_stem}"
            all_videos[key] = {
                "crime_type" : crime_type,
                "video_id"   : video_stem,
                "frames_dir" : vdir,
                "frames"     : frame_files,
            }
    print(f"  Total videos ready: {len(all_videos)}")
    return all_videos


def load_frames_for_video(video_info, frame_interval=1):
    """Read every frame_interval-th .jpg, base64-encode, return dict."""
    frames_data = {}
    vdir        = video_info["frames_dir"]
    frame_files = video_info["frames"]
    video_id    = video_info["video_id"]
    selected    = frame_files[::frame_interval]
    label = "ALL" if frame_interval == 1 else f"every {frame_interval}th"
    print(f"  Loading {len(selected)} frames ({label}) for {video_id} ...")
    for ff in selected:
        fp = os.path.join(vdir, ff)
        try:
            with open(fp, "rb") as fh:
                frames_data[ff] = base64.b64encode(fh.read()).decode("utf-8")
        except Exception as e:
            print(f"    ERROR loading {ff}: {e}")
    print(f"  Loaded {len(frames_data)}/{len(selected)} frames OK")
    return frames_data

SAVE_DIR = r"C:\Opeyemi\PROMPTS\RESULTS\GPT\LEAST-TO-MOST"
os.makedirs(SAVE_DIR, exist_ok=True)


CHECKPOINT_FILE = os.path.join(SAVE_DIR, "least_to_most_checkpoint.json")


def load_checkpoint():
    """Resume from last completed video after any crash or network failure."""
    if os.path.exists(CHECKPOINT_FILE):
        try:
            with open(CHECKPOINT_FILE, "r") as f:
                data = json.load(f)
            n = len(data.get("completed_videos", []))
            print(f"  Checkpoint: {n} videos already done - skipping them.")
            return data
        except Exception as e:
            print(f"  Could not read checkpoint ({e}) - starting fresh.")
    return {"completed_videos": [], "results": {}}


def save_checkpoint(data):
    """Atomic write so the file is never corrupted on a crash."""
    os.makedirs(SAVE_DIR, exist_ok=True)
    tmp = CHECKPOINT_FILE + ".tmp"
    with open(tmp, "w") as f:
        json.dump(data, f, indent=2)
    os.replace(tmp, CHECKPOINT_FILE)








def _build_image_content(frames_data):
    """Convert frames_data dict into GPT vision content blocks, BATCH_SIZE at a time."""
    frame_names = sorted(frames_data.keys(), key=lambda x: extract_frame_number(x))
    batches = [frame_names[i:i+BATCH_SIZE] for i in range(0, len(frame_names), BATCH_SIZE)]
    return batches, frame_names


def _make_payload(api_key, messages):
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }
    payload = {
        "model": "gpt-5.5",
        "messages": messages,
        "max_completion_tokens": 4096
    }
    return headers, payload


def _frames_to_content(frames_data, frame_names):
    """Build a GPT vision content list from a batch of frame names."""
    content = []
    for fname in frame_names:
        b64 = frames_data[fname]
        content.append({
            "type": "image_url",
            "image_url": {
                "url": f"data:image/jpeg;base64,{b64}",
                "detail": "low"
            }
        })
        content.append({"type": "text", "text": f"[Frame: {fname}]"})
    return content


class LeastToMostAnalyzer:
    """
    Least-to-Most crime analysis using GPT-5.5 with BATCH_SIZE frame batching.
    Level 1 processes frames in batches (images), levels 2-5 are text-only.
    """
    def __init__(self, api_key):
        self.api_key = api_key

    def analyze_frames(self, frames_data, video_id, crime_type):
        print(f"\n  [Least-to-Most] {video_id} | {len(frames_data)} frames ...")
        frame_names = sorted(frames_data.keys(), key=lambda x: extract_frame_number(x))
        batches = [frame_names[i:i+BATCH_SIZE] for i in range(0, len(frame_names), BATCH_SIZE)]
        stages = {}

        # Level 1: Basic visual elements (images, batched)
        print(f"    Level 1: Basic visual elements | {len(batches)} batches ...")
        batch_summaries = []
        for idx, batch in enumerate(batches, 1):
            content = _frames_to_content(frames_data, batch)
            content.append({"type": "text", "text": (
                f"LEVEL 1 - Basic Visual Elements only (Batch {idx}/{len(batches)}): "
                "List setting type, number of people, objects present, time of day if determinable, camera quality. Factual only."
            )})
            messages = [{"role": "user", "content": content}]
            headers, payload = _make_payload(self.api_key, messages)
            result = make_gpt_request_robust(headers, payload)
            s = result.get("choices",[{}])[0].get("message",{}).get("content", str(result))
            batch_summaries.append(s)

        formatted = "\n\n".join(f"--- Batch {i+1} ---\n{s}" for i,s in enumerate(batch_summaries))
        synth_msg = [{"role": "user", "content": (
            f"Basic visual observations from {len(frames_data)} frames:\n{formatted}\n\n"
            "Write a unified BASIC VISUAL ELEMENTS summary. Factual only, no interpretation."
        )}]
        headers, payload = _make_payload(self.api_key, synth_msg)
        result = make_gpt_request_robust(headers, payload)
        visual_summary = result.get("choices",[{}])[0].get("message",{}).get("content", str(result))
        stages["level1_batch_summaries"] = batch_summaries
        stages["level1_basic_elements"] = visual_summary
        print(f"      Visual summary: {len(visual_summary)} chars")

        conversation = [
            {"role": "user", "content": f"I analyzed {len(frames_data)} security camera frames. Basic visual elements:\n\n{visual_summary}"},
            {"role": "assistant", "content": "Understood. I have reviewed the basic visual elements and am ready for deeper analysis."}
        ]

        for level_num, (label, prompt) in enumerate([
            ("level2_human_behaviour", "LEVEL 2 - Human Behaviour: Describe body language, movement patterns, facial expressions if visible, hand/arm movements, speed and urgency of actions."),
            ("level3_interactions", "LEVEL 3 - Interactions & Context: How are people interacting with each other and objects? Social dynamics, power imbalances, conflicts, and likely purpose of actions?"),
            ("level4_classification", "LEVEL 4 - Crime Classification: Is a crime occurring? Choose from: Abuse, Arrest, Arson, Assault, Burglary, Explosion, Fighting, RoadAccidents, Robbery, Shooting, Shoplifting, Stealing, Vandalism, Normal. What ruled out other types?"),
            ("level5_final_report", "LEVEL 5 - Final Integrated Report:\nPRIMARY CLASSIFICATION: [crime type]\nCONFIDENCE LEVEL: [0-100%]\nSEVERITY: [Low/Medium/High/Critical]\nEVIDENCE SUMMARY:\n- [point 1]\n- [point 2]\nTIMELINE OF EVENTS: [chronological summary]\nALTERNATIVE INTERPRETATIONS: [other explanations]\nRECOMMENDED LAW ENFORCEMENT RESPONSE: [actions]"),
        ], start=2):
            print(f"    Level {level_num}: {label} ...")
            conversation.append({"role": "user", "content": prompt})
            headers, payload = _make_payload(self.api_key, conversation)
            result = make_gpt_request_robust(headers, payload)
            response = result.get("choices",[{}])[0].get("message",{}).get("content", str(result))
            conversation.append({"role": "assistant", "content": response})
            stages[label] = response
            print(f"      Response: {len(response)} chars")

        return {
            "video_id": video_id, "crime_type": crime_type,
            "frames_analyzed": len(frames_data), "total_batches": len(batches),
            "batch_size": BATCH_SIZE, "prompting_technique": "LEAST-TO-MOST",
            "model": "gpt-5.5", "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
            "stages": stages
        }



def make_gpt_request_robust(headers, payload, max_retries=7, base_wait=5):
    """
    Fault-tolerant OpenAI API call using requests.
    Retries on: rate limits (429), network errors, server errors (5xx).
    Exponential back-off with jitter, capped at 5 minutes.
    Returns parsed JSON on success, or error-string dict on permanent failure.
    """
    import random
    url = "https://api.openai.com/v1/chat/completions"

    for attempt in range(1, max_retries + 1):
        try:
            response = requests.post(url, headers=headers, json=payload, timeout=120)

            if response.status_code == 200:
                return response.json()

            # Rate limit
            if response.status_code == 429:
                wait = base_wait * (2 ** (attempt - 1)) + random.uniform(0, 2)
                wait = min(wait, 300)
                print(f"[Retry {attempt}/{max_retries}] 429 Rate limit. Waiting {wait:.1f}s ...")
                time.sleep(wait)
                continue

            # Server errors – retry
            if response.status_code >= 500:
                wait = base_wait * (2 ** (attempt - 1)) + random.uniform(0, 2)
                wait = min(wait, 300)
                print(f"[Retry {attempt}/{max_retries}] HTTP {response.status_code}. Waiting {wait:.1f}s ...")
                time.sleep(wait)
                continue

            # Permanent client errors (4xx except 429) – do not retry
            try:
                err = response.json()
            except Exception:
                err = response.text
            print(f"[FATAL] HTTP {response.status_code}: {err}")
            return {"error": f"HTTP_{response.status_code}", "detail": str(err)}

        except (requests.exceptions.ConnectionError,
                requests.exceptions.Timeout,
                requests.exceptions.ChunkedEncodingError) as e:
            wait = base_wait * (2 ** (attempt - 1)) + random.uniform(0, 2)
            wait = min(wait, 300)
            print(f"[Retry {attempt}/{max_retries}] Network error: {type(e).__name__}: {e}")
            print(f"  Waiting {wait:.1f}s ...")
            time.sleep(wait)

        except Exception as e:
            if attempt < max_retries:
                print(f"[Retry {attempt}/{max_retries}] Unexpected: {type(e).__name__}: {e}")
                time.sleep(base_wait * attempt)
            else:
                return {"error": str(e)}

    return {"error": f"All {max_retries} attempts exhausted"}





def process_all_crime_folders(api_key):
    """
    Analyse every video in FRAMES_DIR.
    Already-completed videos are skipped (checkpoint/resume) so re-running
    after any failure picks up exactly where it stopped.
    """
    analyzer   = LeastToMostAnalyzer(api_key)
    all_videos = discover_all_videos_and_frames()
    if not all_videos:
        print("No videos found! Verify FRAMES_DIR path."); return {}
    cp          = load_checkpoint()
    all_results = cp.get("results", {})
    done_set    = set(cp.get("completed_videos", []))
    skipped     = []
    total       = len(all_videos)
    remaining   = {k: v for k, v in all_videos.items() if k not in done_set}
    print(f"\nVideos: total={total} | done={len(done_set)} | remaining={len(remaining)}")
    # ================================================================
    #  PARALLEL VIDEO PROCESSING
    # ================================================================
    checkpoint_lock = threading.Lock()
    print_lock      = threading.Lock()

    def _process_one_video(vkey, vinfo):
        """Process a single video in its own thread. Checkpoint writes are locked."""
        with print_lock:
            print(f"\n  [START] {vkey}")
        try:
            frames = load_frames_for_video(vinfo, FRAME_INTERVAL)
            if not frames:
                return vkey, None, "no frames"
            res = analyzer.analyze_frames(frames, vinfo["video_id"], vinfo["crime_type"])
            with checkpoint_lock:
                all_results[vkey] = res
                done_set.add(vkey)
                save_checkpoint({"completed_videos": list(done_set), "results": all_results})
            with print_lock:
                print(f"  [DONE]  {vkey}  ({len(done_set)}/{total})")
            return vkey, res, None
        except Exception as e:
            with print_lock:
                print(f"  [ERROR] {vkey}: {e}")
            with checkpoint_lock:
                save_checkpoint({"completed_videos": list(done_set), "results": all_results})
            return vkey, None, f"error: {e}"

    print(f"\n  Launching ThreadPoolExecutor with {MAX_WORKERS} parallel workers ...")
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(_process_one_video, k, v) for k, v in remaining.items()]
        for fut in as_completed(futures):
            vkey, _, err = fut.result()
            if err:
                skipped.append(f"{vkey} ({err})")

    ts = time.strftime("%Y%m%d_%H%M%S")
    summary = os.path.join(SAVE_DIR, f"ltm_summary_{ts}.json")
    with open(summary, "w") as f:
        json.dump(all_results, f, indent=2)
    if skipped:
        with open(os.path.join(SAVE_DIR, f"skipped_{ts}.txt"), "w") as f:
            f.write("\n".join(skipped))
    print(f"\nDone. Summary -> {summary}")
    print(f"  Processed: {len(all_results)} | Skipped: {len(skipped)}")
    return all_results


def run():
    # Load API key from file
    with open(r"C:\Opeyemi\PROMPTS\API-KEYS\chatgpt.txt", "r") as _f:
        api_key = _f.read().strip()

    """Main execution function"""
    print("Least-To-Most Prompting Crime Video Analysis - ALL Frames")
    print("="*50)

    # Test directory access first
    print("Testing directory access...")
    for path in [FRAMES_DIR, SAVE_DIR]:
        print(f"Path: {path}")
        print(f"  Exists: {os.path.exists(path)}")
        if os.path.exists(path):
            try:
                contents = os.listdir(path)
                print(f"  Contains {len(contents)} items")
                if contents:
                    print(f"  First few items: {contents[:3]}")
            except Exception as e:
                print(f"  Error accessing contents: {str(e)}")

    # Get API key
    try:
        api_key_path = "C:\Opeyemi\PROMPTS\API-KEYS\chatgpt.txt"
        print(f"Trying to load API key from: {api_key_path}")
        print(f"File exists: {os.path.exists(api_key_path)}")

        f = open(api_key_path, "r")
        api_key = f.read().strip()
        f.close()

        if not api_key:
            print("✗ Failed to load GPT API key: File is empty")
            return

        print("✓ Successfully loaded GPT API key")
        print(f"API key starts with: {api_key[:5]}...")

    except Exception as e:
        print(f"✗ Failed to load GPT API key: {str(e)}")
        return

    # Verify directories exist
    print("\nVerifying directories:")
    print(f"Frames directory exists: {os.path.exists(FRAMES_DIR)}")
    print(f"Save directory exists: {os.path.exists(SAVE_DIR)}")

    if not os.path.exists(FRAMES_DIR):
        print(f"✗ Frames directory not found: {FRAMES_DIR}")
        return

    # Create save directory if it doesn't exist
    os.makedirs(SAVE_DIR, exist_ok=True)

    # Process all crime folders
    results = process_all_crime_folders(api_key)

    print("\n" + "="*50)
    print(f"LEAST-TO-MOST PROMPTING COMPLETE!")
    print(f"Videos processed: {len(results)}")
    print("="*50)

if __name__ == "__main__":
    run()
# Out:
# Least-To-Most Prompting Crime Video Analysis - ALL Frames
# ==================================================
# Testing directory access...
# Path: C:\Opeyemi\PROMPTS\FRAMES
#   Exists: True
#   Contains 13 items
#   First few items: ['Abuse', 'Assault', 'Burglary']
# Path: C:\Opeyemi\PROMPTS\RESULTS\GPT\LEAST-TO-MOST
#   Exists: True
#   Contains 1 items
#   First few items: ['least_to_most_checkpoint.json']
# Trying to load API key from: C:\Opeyemi\PROMPTS\API-KEYS\chatgpt.txt
# File exists: True
# ✓ Successfully loaded GPT API key
# API key starts with: sk-pr...
#
# Verifying directories:
# Frames directory exists: True
# Save directory exists: True
#
# === DISCOVERING FRAMES ===
#     Root : C:\Opeyemi\PROMPTS\FRAMES
#   Categories : ['Abuse', 'Assault', 'Burglary', 'Explosion', 'Fighting', 'RoadAccidents', 'Robbery', 'Shooting', 'Shoplifting', 'Stealing', 'Vandalism']
#     Abuse               : 50 videos
#     Assault             : 12 videos
#     Burglary            : 100 videos
#     Explosion           : 50 videos
#     Fighting            : 50 videos
#     RoadAccidents       : 150 videos
#     Robbery             : 150 videos
#     Shooting            : 50 videos
#     Shoplifting         : 50 videos
#     Stealing            : 100 videos
#     Vandalism           : 50 videos
#   Total videos ready: 812
#   Checkpoint: 46 videos already done - skipping them.
#
# Videos: total=812 | done=46 | remaining=766
#
#   Launching ThreadPoolExecutor with 4 parallel workers ...
#
#   [START] Abuse_Abuse042_x264
#   Loading 949 frames (ALL) for Abuse042_x264 ...
#
#   [START] Abuse_Abuse048_x264
#   Loading 114 frames (ALL) for Abuse048_x264 ...
#
#   [START] Abuse_Abuse049_x264
#   Loading 71 frames (ALL) for Abuse049_x264 ...
#
#   [START] Abuse_Abuse050_x264
#   Loading 162 frames (ALL) for Abuse050_x264 ...
#   Loaded 71/71 frames OK
#
#   [Least-to-Most] Abuse049_x264 | 71 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#   Loaded 114/114 frames OK
#
#   [Least-to-Most] Abuse048_x264 | 114 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#   Loaded 162/162 frames OK
#
#   [Least-to-Most] Abuse050_x264 | 162 frames ...
#     Level 1: Basic visual elements | 9 batches ...
#   Loaded 949/949 frames OK
#
#   [Least-to-Most] Abuse042_x264 | 949 frames ...
#     Level 1: Basic visual elements | 48 batches ...
#       Visual summary: 934 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2904 chars
#     Level 3: level3_interactions ...
#       Visual summary: 1186 chars
#     Level 2: level2_human_behaviour ...
#       Response: 4061 chars
#     Level 4: level4_classification ...
#       Response: 2572 chars
#     Level 5: level5_final_report ...
#       Response: 4514 chars
#     Level 3: level3_interactions ...
#       Visual summary: 934 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2560 chars
#   [DONE]  Abuse_Abuse049_x264  (47/812)
#
#   [START] Assault_Assault007_x264
#   Loading 65 frames (ALL) for Assault007_x264 ...
#   Loaded 65/65 frames OK
#
#   [Least-to-Most] Assault007_x264 | 65 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Response: 2728 chars
#     Level 3: level3_interactions ...
#       Response: 7451 chars
#     Level 4: level4_classification ...
#       Response: 3656 chars
#     Level 4: level4_classification ...
#       Response: 3588 chars
#     Level 5: level5_final_report ...
#       Response: 1952 chars
#     Level 5: level5_final_report ...
#       Visual summary: 852 chars
#     Level 2: level2_human_behaviour ...
#       Response: 4735 chars
#   [DONE]  Abuse_Abuse048_x264  (48/812)
#
#   [START] Assault_Assault012_x264
#   Loading 26 frames (ALL) for Assault012_x264 ...
#   Loaded 26/26 frames OK
#
#   [Least-to-Most] Assault012_x264 | 26 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2652 chars
#   [DONE]  Abuse_Abuse050_x264  (49/812)
#
#   [START] Assault_Assault026_x264
#   Loading 28 frames (ALL) for Assault026_x264 ...
#   Loaded 28/28 frames OK
#
#   [Least-to-Most] Assault026_x264 | 28 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 4039 chars
#     Level 3: level3_interactions ...
#       Visual summary: 771 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 642 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2947 chars
#     Level 3: level3_interactions ...
#       Response: 2175 chars
#     Level 3: level3_interactions ...
#       Response: 7635 chars
#     Level 4: level4_classification ...
#       Response: 2790 chars
#     Level 4: level4_classification ...
#       Response: 4343 chars
#     Level 4: level4_classification ...
#       Response: 3444 chars
#     Level 5: level5_final_report ...
#       Response: 2112 chars
#     Level 5: level5_final_report ...
#       Response: 2947 chars
#     Level 5: level5_final_report ...
#       Response: 2931 chars
#   [DONE]  Assault_Assault026_x264  (50/812)
#
#   [START] Assault_Assault033_x264
#   Loading 43 frames (ALL) for Assault033_x264 ...
#   Loaded 43/43 frames OK
#
#   [Least-to-Most] Assault033_x264 | 43 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 2519 chars
#   [DONE]  Assault_Assault012_x264  (51/812)
#
#   [START] Assault_Assault035_x264
#   Loading 30 frames (ALL) for Assault035_x264 ...
#   Loaded 30/30 frames OK
#
#   [Least-to-Most] Assault035_x264 | 30 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 4640 chars
#   [DONE]  Assault_Assault007_x264  (52/812)
#
#   [START] Assault_Assault036_x264
#   Loading 30 frames (ALL) for Assault036_x264 ...
#   Loaded 30/30 frames OK
#
#   [Least-to-Most] Assault036_x264 | 30 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Visual summary: 769 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 672 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 713 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1990 chars
#     Level 3: level3_interactions ...
#       Response: 3458 chars
#     Level 3: level3_interactions ...
#       Response: 2971 chars
#     Level 4: level4_classification ...
#       Response: 2786 chars
#     Level 3: level3_interactions ...
#       Response: 2494 chars
#     Level 5: level5_final_report ...
#       Response: 4763 chars
#     Level 4: level4_classification ...
#       Response: 2381 chars
#   [DONE]  Assault_Assault033_x264  (53/812)
#
#   [START] Assault_Assault038_x264
#   Loading 5 frames (ALL) for Assault038_x264 ...
#   Loaded 5/5 frames OK
#
#   [Least-to-Most] Assault038_x264 | 5 frames ...
#     Level 1: Basic visual elements | 1 batches ...
#       Response: 5453 chars
#     Level 4: level4_classification ...
#       Visual summary: 313 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3322 chars
#     Level 5: level5_final_report ...
#       Response: 2382 chars
#     Level 5: level5_final_report ...
#       Response: 1784 chars
#     Level 3: level3_interactions ...
#       Response: 3183 chars
#   [DONE]  Assault_Assault035_x264  (54/812)
#
#   [START] Assault_Assault039_x264
#   Loading 10 frames (ALL) for Assault039_x264 ...
#   Loaded 10/10 frames OK
#
#   [Least-to-Most] Assault039_x264 | 10 frames ...
#     Level 1: Basic visual elements | 1 batches ...
#       Response: 3778 chars
#   [DONE]  Assault_Assault036_x264  (55/812)
#
#   [START] Assault_Assault044_x264
#   Loading 25 frames (ALL) for Assault044_x264 ...
#   Loaded 25/25 frames OK
#
#   [Least-to-Most] Assault044_x264 | 25 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Visual summary: 865 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3307 chars
#     Level 4: level4_classification ...
#       Visual summary: 520 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2160 chars
#     Level 5: level5_final_report ...
#       Response: 2514 chars
#     Level 3: level3_interactions ...
#       Response: 1619 chars
#     Level 3: level3_interactions ...
#       Visual summary: 1001 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2234 chars
#   [DONE]  Assault_Assault038_x264  (56/812)
#
#   [START] Assault_Assault046_x264
#   Loading 32 frames (ALL) for Assault046_x264 ...
#   Loaded 32/32 frames OK
#
#   [Least-to-Most] Assault046_x264 | 32 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 3017 chars
#     Level 4: level4_classification ...
#       Response: 2515 chars
#     Level 4: level4_classification ...
#       Response: 3639 chars
#     Level 3: level3_interactions ...
#       Response: 2247 chars
#     Level 5: level5_final_report ...
#       Response: 2584 chars
#     Level 5: level5_final_report ...
#       Visual summary: 688 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2567 chars
#   [DONE]  Assault_Assault039_x264  (57/812)
#
#   [START] Assault_Assault049_x264
#   Loading 44 frames (ALL) for Assault049_x264 ...
#   Loaded 44/44 frames OK
#
#   [Least-to-Most] Assault049_x264 | 44 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 3046 chars
#   [DONE]  Abuse_Abuse042_x264  (58/812)
#
#   [START] Assault_Assault052_x264
#   Loading 26 frames (ALL) for Assault052_x264 ...
#   Loaded 26/26 frames OK
#
#   [Least-to-Most] Assault052_x264 | 26 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2302 chars
#     Level 3: level3_interactions ...
#       Response: 5594 chars
#     Level 4: level4_classification ...
#       Visual summary: 715 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3366 chars
#     Level 4: level4_classification ...
#       Visual summary: 680 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3151 chars
#     Level 5: level5_final_report ...
#       Response: 2122 chars
#     Level 3: level3_interactions ...
#       Response: 2479 chars
#     Level 5: level5_final_report ...
#       Response: 2636 chars
#     Level 3: level3_interactions ...
#       Response: 3734 chars
#   [DONE]  Assault_Assault044_x264  (59/812)
#
#   [START] Burglary_Burglary001_x264
#   Loading 132 frames (ALL) for Burglary001_x264 ...
#   Loaded 132/132 frames OK
#
#   [Least-to-Most] Burglary001_x264 | 132 frames ...
#     Level 1: Basic visual elements | 7 batches ...
#       Response: 2507 chars
#   [DONE]  Assault_Assault046_x264  (60/812)
#
#   [START] Burglary_Burglary002_x264
#   Loading 102 frames (ALL) for Burglary002_x264 ...
#   Loaded 102/102 frames OK
#
#   [Least-to-Most] Burglary002_x264 | 102 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#       Response: 3757 chars
#     Level 4: level4_classification ...
#       Response: 3983 chars
#     Level 4: level4_classification ...
#       Response: 2408 chars
#     Level 5: level5_final_report ...
#       Response: 2431 chars
#     Level 5: level5_final_report ...
#       Response: 2589 chars
#   [DONE]  Assault_Assault052_x264  (61/812)
#
#   [START] Burglary_Burglary003_x264
#   Loading 39 frames (ALL) for Burglary003_x264 ...
#   Loaded 39/39 frames OK
#
#   [Least-to-Most] Burglary003_x264 | 39 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 3548 chars
#   [DONE]  Assault_Assault049_x264  (62/812)
#
#   [START] Burglary_Burglary004_x264
#   Loading 60 frames (ALL) for Burglary004_x264 ...
#   Loaded 60/60 frames OK
#
#   [Least-to-Most] Burglary004_x264 | 60 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Visual summary: 898 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 679 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 1019 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2077 chars
#     Level 3: level3_interactions ...
#       Response: 2390 chars
#     Level 3: level3_interactions ...
#       Response: 2370 chars
#     Level 3: level3_interactions ...
#       Visual summary: 818 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2131 chars
#     Level 4: level4_classification ...
#       Response: 3137 chars
#     Level 4: level4_classification ...
#       Response: 2355 chars
#     Level 5: level5_final_report ...
#       Response: 4390 chars
#     Level 4: level4_classification ...
#       Response: 2951 chars
#     Level 3: level3_interactions ...
#       Response: 2503 chars
#     Level 5: level5_final_report ...
#       Response: 2755 chars
#   [DONE]  Burglary_Burglary003_x264  (63/812)
#
#   [START] Burglary_Burglary005_x264
#   Loading 258 frames (ALL) for Burglary005_x264 ...
#   Loaded 258/258 frames OK
#
#   [Least-to-Most] Burglary005_x264 | 258 frames ...
#     Level 1: Basic visual elements | 13 batches ...
#       Response: 3353 chars
#     Level 5: level5_final_report ...
#       Response: 4192 chars
#     Level 4: level4_classification ...
#       Response: 4160 chars
#   [DONE]  Burglary_Burglary002_x264  (64/812)
#
#   [START] Burglary_Burglary006_x264
#   Loading 298 frames (ALL) for Burglary006_x264 ...
#   Loaded 298/298 frames OK
#
#   [Least-to-Most] Burglary006_x264 | 298 frames ...
#     Level 1: Basic visual elements | 15 batches ...
#       Response: 3541 chars
#   [DONE]  Burglary_Burglary001_x264  (65/812)
#
#   [START] Burglary_Burglary007_x264
#   Loading 36 frames (ALL) for Burglary007_x264 ...
#   Loaded 36/36 frames OK
#
#   [Least-to-Most] Burglary007_x264 | 36 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2218 chars
#     Level 5: level5_final_report ...
#       Visual summary: 949 chars
#     Level 2: level2_human_behaviour ...
#       Response: 4120 chars
#   [DONE]  Burglary_Burglary004_x264  (66/812)
#
#   [START] Burglary_Burglary008_x264
#   Loading 164 frames (ALL) for Burglary008_x264 ...
#   Loaded 164/164 frames OK
#
#   [Least-to-Most] Burglary008_x264 | 164 frames ...
#     Level 1: Basic visual elements | 9 batches ...
#       Response: 2617 chars
#     Level 3: level3_interactions ...
#       Response: 4847 chars
#     Level 4: level4_classification ...
#       Visual summary: 1057 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3376 chars
#     Level 5: level5_final_report ...
#       Visual summary: 829 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3038 chars
#     Level 3: level3_interactions ...
#       Response: 3467 chars
#     Level 3: level3_interactions ...
#       Response: 4032 chars
#   [DONE]  Burglary_Burglary007_x264  (67/812)
#
#   [START] Burglary_Burglary009_x264
#   Loading 85 frames (ALL) for Burglary009_x264 ...
#   Loaded 85/85 frames OK
#
#   [Least-to-Most] Burglary009_x264 | 85 frames ...
#     Level 1: Basic visual elements | 5 batches ...
#       Response: 5143 chars
#     Level 4: level4_classification ...
#       Response: 3567 chars
#     Level 4: level4_classification ...
#       Response: 2400 chars
#     Level 5: level5_final_report ...
#       Visual summary: 2104 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3027 chars
#     Level 5: level5_final_report ...
#       Response: 2947 chars
#   [DONE]  Burglary_Burglary005_x264  (68/812)
#
#   [START] Burglary_Burglary010_x264
#   Loading 196 frames (ALL) for Burglary010_x264 ...
#   Loaded 196/196 frames OK
#
#   [Least-to-Most] Burglary010_x264 | 196 frames ...
#     Level 1: Basic visual elements | 10 batches ...
#       Response: 2878 chars
#   [DONE]  Burglary_Burglary006_x264  (69/812)
#
#   [START] Burglary_Burglary011_x264
#   Loading 65 frames (ALL) for Burglary011_x264 ...
#   Loaded 65/65 frames OK
#
#   [Least-to-Most] Burglary011_x264 | 65 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Visual summary: 770 chars
#     Level 2: level2_human_behaviour ...
#       Response: 5676 chars
#     Level 3: level3_interactions ...
#       Response: 2891 chars
#     Level 3: level3_interactions ...
#       Response: 7943 chars
#     Level 4: level4_classification ...
#       Visual summary: 920 chars
#     Level 2: level2_human_behaviour ...
#       Response: 4358 chars
#     Level 4: level4_classification ...
#       Response: 3176 chars
#     Level 3: level3_interactions ...
#       Response: 3647 chars
#     Level 5: level5_final_report ...
#       Response: 2589 chars
#     Level 5: level5_final_report ...
#       Response: 4644 chars
#     Level 4: level4_classification ...
#       Response: 3532 chars
#   [DONE]  Burglary_Burglary009_x264  (70/812)
#
#   [START] Burglary_Burglary012_x264
#   Loading 57 frames (ALL) for Burglary012_x264 ...
#   Loaded 57/57 frames OK
#
#   [Least-to-Most] Burglary012_x264 | 57 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 4998 chars
#   [DONE]  Burglary_Burglary008_x264  (71/812)
#
#   [START] Burglary_Burglary013_x264
#   Loading 74 frames (ALL) for Burglary013_x264 ...
#   Loaded 74/74 frames OK
#
#   [Least-to-Most] Burglary013_x264 | 74 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Visual summary: 841 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3200 chars
#     Level 5: level5_final_report ...
#       Response: 3873 chars
#   [DONE]  Burglary_Burglary011_x264  (72/812)
#
#   [START] Burglary_Burglary014_x264
#   Loading 86 frames (ALL) for Burglary014_x264 ...
#   Loaded 86/86 frames OK
#
#   [Least-to-Most] Burglary014_x264 | 86 frames ...
#     Level 1: Basic visual elements | 5 batches ...
#       Response: 3011 chars
#     Level 3: level3_interactions ...
#       Visual summary: 754 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 947 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2712 chars
#     Level 3: level3_interactions ...
#       Response: 4622 chars
#     Level 4: level4_classification ...
#       Response: 2626 chars
#     Level 3: level3_interactions ...
#       Response: 3912 chars
#     Level 4: level4_classification ...
#       Response: 3529 chars
#     Level 5: level5_final_report ...
#       Visual summary: 805 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2271 chars
#     Level 5: level5_final_report ...
#       Response: 3354 chars
#     Level 4: level4_classification ...
#       Response: 2032 chars
#     Level 3: level3_interactions ...
#       Response: 3762 chars
#   [DONE]  Burglary_Burglary010_x264  (73/812)
#
#   [START] Burglary_Burglary015_x264
#   Loading 37 frames (ALL) for Burglary015_x264 ...
#   Loaded 37/37 frames OK
#
#   [Least-to-Most] Burglary015_x264 | 37 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2670 chars
#   [DONE]  Burglary_Burglary012_x264  (74/812)
#
#   [START] Burglary_Burglary016_x264
#   Loading 175 frames (ALL) for Burglary016_x264 ...
#   Loaded 175/175 frames OK
#
#   [Least-to-Most] Burglary016_x264 | 175 frames ...
#     Level 1: Basic visual elements | 9 batches ...
#       Response: 2155 chars
#     Level 5: level5_final_report ...
#       Response: 3495 chars
#     Level 4: level4_classification ...
#       Response: 2549 chars
#     Level 5: level5_final_report ...
#       Response: 3530 chars
#   [DONE]  Burglary_Burglary013_x264  (75/812)
#
#   [START] Burglary_Burglary017_x264
#   Loading 70 frames (ALL) for Burglary017_x264 ...
#   Loaded 70/70 frames OK
#
#   [Least-to-Most] Burglary017_x264 | 70 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Visual summary: 856 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2730 chars
#   [DONE]  Burglary_Burglary014_x264  (76/812)
#
#   [START] Burglary_Burglary018_x264
#   Loading 38 frames (ALL) for Burglary018_x264 ...
#   Loaded 38/38 frames OK
#
#   [Least-to-Most] Burglary018_x264 | 38 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 3645 chars
#     Level 3: level3_interactions ...
#       Visual summary: 598 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 861 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1664 chars
#     Level 3: level3_interactions ...
#       Visual summary: 723 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2454 chars
#     Level 4: level4_classification ...
#       Response: 5981 chars
#     Level 4: level4_classification ...
#       Response: 2591 chars
#     Level 3: level3_interactions ...
#       Response: 2858 chars
#     Level 3: level3_interactions ...
#       Response: 2173 chars
#     Level 5: level5_final_report ...
#       Response: 2877 chars
#     Level 5: level5_final_report ...
#       Response: 4446 chars
#     Level 4: level4_classification ...
#       Response: 2794 chars
#   [DONE]  Burglary_Burglary018_x264  (77/812)
#
#   [START] Burglary_Burglary019_x264
#   Loading 96 frames (ALL) for Burglary019_x264 ...
#   Loaded 96/96 frames OK
#
#   [Least-to-Most] Burglary019_x264 | 96 frames ...
#     Level 1: Basic visual elements | 5 batches ...
#       Response: 2677 chars
#   [DONE]  Burglary_Burglary015_x264  (78/812)
#
#   [START] Burglary_Burglary020_x264
#   Loading 110 frames (ALL) for Burglary020_x264 ...
#   Loaded 110/110 frames OK
#
#   [Least-to-Most] Burglary020_x264 | 110 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#       Response: 2650 chars
#     Level 5: level5_final_report ...
#       Response: 5304 chars
#     Level 4: level4_classification ...
#       Response: 3478 chars
#     Level 5: level5_final_report ...
#       Response: 3733 chars
#   [DONE]  Burglary_Burglary017_x264  (79/812)
#
#   [START] Burglary_Burglary021_x264
#   Loading 51 frames (ALL) for Burglary021_x264 ...
#   Loaded 51/51 frames OK
#
#   [Least-to-Most] Burglary021_x264 | 51 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 4360 chars
#   [DONE]  Burglary_Burglary016_x264  (80/812)
#
#   [START] Burglary_Burglary022_x264
#   Loading 95 frames (ALL) for Burglary022_x264 ...
#   Loaded 95/95 frames OK
#
#   [Least-to-Most] Burglary022_x264 | 95 frames ...
#     Level 1: Basic visual elements | 5 batches ...
#       Visual summary: 1116 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 672 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 827 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2257 chars
#     Level 3: level3_interactions ...
#       Response: 3833 chars
#     Level 3: level3_interactions ...
#       Response: 3001 chars
#     Level 3: level3_interactions ...
#       Response: 2870 chars
#     Level 4: level4_classification ...
#       Visual summary: 833 chars
#     Level 2: level2_human_behaviour ...
#       Response: 4909 chars
#     Level 4: level4_classification ...
#       Response: 6731 chars
#     Level 4: level4_classification ...
#       Response: 2589 chars
#     Level 5: level5_final_report ...
#       Response: 3309 chars
#     Level 3: level3_interactions ...
#       Response: 3184 chars
#   [DONE]  Burglary_Burglary021_x264  (81/812)
#
#   [START] Burglary_Burglary023_x264
#   Loading 331 frames (ALL) for Burglary023_x264 ...
#       Response: 3425 chars
#     Level 5: level5_final_report ...
#   Loaded 331/331 frames OK
#
#   [Least-to-Most] Burglary023_x264 | 331 frames ...
#     Level 1: Basic visual elements | 17 batches ...
#       Response: 2753 chars
#     Level 5: level5_final_report ...
#       Response: 4126 chars
#     Level 4: level4_classification ...
#       Response: 3627 chars
#   [DONE]  Burglary_Burglary020_x264  (82/812)
#
#   [START] Burglary_Burglary024_x264
#   Loading 120 frames (ALL) for Burglary024_x264 ...
#   Loaded 120/120 frames OK
#
#   [Least-to-Most] Burglary024_x264 | 120 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#       Response: 4769 chars
#   [DONE]  Burglary_Burglary019_x264  (83/812)
#
#   [START] Burglary_Burglary025_x264
#   Loading 207 frames (ALL) for Burglary025_x264 ...
#   Loaded 207/207 frames OK
#
#   [Least-to-Most] Burglary025_x264 | 207 frames ...
#     Level 1: Basic visual elements | 11 batches ...
#       Response: 3225 chars
#     Level 5: level5_final_report ...
#       Response: 3238 chars
#   [DONE]  Burglary_Burglary022_x264  (84/812)
#
#   [START] Burglary_Burglary026_x264
#   Loading 51 frames (ALL) for Burglary026_x264 ...
#   Loaded 51/51 frames OK
#
#   [Least-to-Most] Burglary026_x264 | 51 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Visual summary: 691 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 786 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1871 chars
#     Level 3: level3_interactions ...
#       Response: 2487 chars
#     Level 3: level3_interactions ...
#       Response: 2416 chars
#     Level 4: level4_classification ...
#       Response: 2504 chars
#     Level 4: level4_classification ...
#       Visual summary: 851 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2181 chars
#     Level 5: level5_final_report ...
#       Response: 2444 chars
#     Level 5: level5_final_report ...
#       Response: 2024 chars
#     Level 3: level3_interactions ...
#       Response: 2373 chars
#   [DONE]  Burglary_Burglary026_x264  (85/812)
#
#   [START] Burglary_Burglary027_x264
#   Loading 103 frames (ALL) for Burglary027_x264 ...
#   Loaded 103/103 frames OK
#
#   [Least-to-Most] Burglary027_x264 | 103 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#       Visual summary: 909 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2618 chars
#   [DONE]  Burglary_Burglary024_x264  (86/812)
#
#   [START] Burglary_Burglary028_x264
#   Loading 32 frames (ALL) for Burglary028_x264 ...
#   Loaded 32/32 frames OK
#
#   [Least-to-Most] Burglary028_x264 | 32 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2326 chars
#     Level 4: level4_classification ...
#       Response: 2083 chars
#     Level 5: level5_final_report ...
#       Response: 2818 chars
#     Level 3: level3_interactions ...
#       Visual summary: 739 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2551 chars
#   [DONE]  Burglary_Burglary025_x264  (87/812)
#
#   [START] Burglary_Burglary029_x264
#   Loading 167 frames (ALL) for Burglary029_x264 ...
#   Loaded 167/167 frames OK
#
#   [Least-to-Most] Burglary029_x264 | 167 frames ...
#     Level 1: Basic visual elements | 9 batches ...
#       Response: 3118 chars
#     Level 4: level4_classification ...
#       Response: 2482 chars
#     Level 3: level3_interactions ...
#       Response: 3410 chars
#     Level 5: level5_final_report ...
#       Response: 3432 chars
#     Level 4: level4_classification ...
#       Visual summary: 906 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3512 chars
#   [DONE]  Burglary_Burglary023_x264  (88/812)
#
#   [START] Burglary_Burglary030_x264
#   Loading 30 frames (ALL) for Burglary030_x264 ...
#   Loaded 30/30 frames OK
#
#   [Least-to-Most] Burglary030_x264 | 30 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2487 chars
#     Level 5: level5_final_report ...
#       Response: 3252 chars
#     Level 3: level3_interactions ...
#       Response: 2926 chars
#   [DONE]  Burglary_Burglary028_x264  (89/812)
#
#   [START] Burglary_Burglary031_x264
#   Loading 209 frames (ALL) for Burglary031_x264 ...
#   Loaded 209/209 frames OK
#
#   [Least-to-Most] Burglary031_x264 | 209 frames ...
#     Level 1: Basic visual elements | 11 batches ...
#       Visual summary: 763 chars
#     Level 2: level2_human_behaviour ...
#       Response: 5296 chars
#     Level 4: level4_classification ...
#       Visual summary: 1601 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3137 chars
#     Level 3: level3_interactions ...
#       Response: 3277 chars
#     Level 5: level5_final_report ...
#       Response: 4184 chars
#     Level 3: level3_interactions ...
#       Response: 5140 chars
#     Level 4: level4_classification ...
#       Response: 4810 chars
#   [DONE]  Burglary_Burglary027_x264  (90/812)
#
#   [START] Burglary_Burglary032_x264
#   Loading 527 frames (ALL) for Burglary032_x264 ...
#   Loaded 527/527 frames OK
#
#   [Least-to-Most] Burglary032_x264 | 527 frames ...
#     Level 1: Basic visual elements | 27 batches ...
#       Response: 3051 chars
#     Level 5: level5_final_report ...
#       Response: 4483 chars
#     Level 4: level4_classification ...
#       Response: 2884 chars
#   [DONE]  Burglary_Burglary030_x264  (91/812)
#
#   [START] Burglary_Burglary033_x264
#   Loading 42 frames (ALL) for Burglary033_x264 ...
#   Loaded 42/42 frames OK
#
#   [Least-to-Most] Burglary033_x264 | 42 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 3075 chars
#     Level 5: level5_final_report ...
#       Visual summary: 923 chars
#     Level 2: level2_human_behaviour ...
#       Response: 4310 chars
#   [DONE]  Burglary_Burglary029_x264  (92/812)
#
#   [START] Burglary_Burglary034_x264
#   Loading 43 frames (ALL) for Burglary034_x264 ...
#   Loaded 43/43 frames OK
#
#   [Least-to-Most] Burglary034_x264 | 43 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Visual summary: 728 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2469 chars
#     Level 3: level3_interactions ...
#       Response: 4263 chars
#     Level 3: level3_interactions ...
#       Response: 2756 chars
#     Level 4: level4_classification ...
#       Response: 2195 chars
#     Level 5: level5_final_report ...
#       Response: 5521 chars
#     Level 4: level4_classification ...
#       Visual summary: 832 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2750 chars
#   [DONE]  Burglary_Burglary033_x264  (93/812)
#
#   [START] Burglary_Burglary035_x264
#   Loading 135 frames (ALL) for Burglary035_x264 ...
#   Loaded 135/135 frames OK
#
#   [Least-to-Most] Burglary035_x264 | 135 frames ...
#     Level 1: Basic visual elements | 7 batches ...
#       Response: 2785 chars
#     Level 3: level3_interactions ...
#       Response: 3260 chars
#     Level 5: level5_final_report ...
#       Response: 3708 chars
#     Level 4: level4_classification ...
#       Response: 3866 chars
#   [DONE]  Burglary_Burglary031_x264  (94/812)
#
#   [START] Burglary_Burglary036_x264
#   Loading 33 frames (ALL) for Burglary036_x264 ...
#   Loaded 33/33 frames OK
#
#   [Least-to-Most] Burglary036_x264 | 33 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2897 chars
#     Level 5: level5_final_report ...
#       Visual summary: 472 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3161 chars
#   [DONE]  Burglary_Burglary034_x264  (95/812)
#
#   [START] Burglary_Burglary037_x264
#   Loading 64 frames (ALL) for Burglary037_x264 ...
#   Loaded 64/64 frames OK
#
#   [Least-to-Most] Burglary037_x264 | 64 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Response: 2539 chars
#     Level 3: level3_interactions ...
#       Visual summary: 887 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2998 chars
#     Level 4: level4_classification ...
#       Response: 3281 chars
#     Level 3: level3_interactions ...
#       Visual summary: 1019 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2348 chars
#     Level 5: level5_final_report ...
#       Response: 2250 chars
#   [DONE]  Burglary_Burglary036_x264  (96/812)
#
#   [START] Burglary_Burglary038_x264
#   Loading 30 frames (ALL) for Burglary038_x264 ...
#   Loaded 30/30 frames OK
#
#   [Least-to-Most] Burglary038_x264 | 30 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 3534 chars
#     Level 3: level3_interactions ...
#       Response: 4238 chars
#     Level 4: level4_classification ...
#       Visual summary: 544 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3154 chars
#     Level 5: level5_final_report ...
#       Response: 4672 chars
#     Level 4: level4_classification ...
#       Visual summary: 912 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1826 chars
#     Level 3: level3_interactions ...
#       Response: 3832 chars
#   [DONE]  Burglary_Burglary035_x264  (97/812)
#
#   [START] Burglary_Burglary039_x264
#   Loading 314 frames (ALL) for Burglary039_x264 ...
#   Loaded 314/314 frames OK
#
#   [Least-to-Most] Burglary039_x264 | 314 frames ...
#     Level 1: Basic visual elements | 16 batches ...
#       Response: 2496 chars
#     Level 4: level4_classification ...
#       Response: 2901 chars
#     Level 5: level5_final_report ...
#       Response: 2303 chars
#     Level 3: level3_interactions ...
#       Response: 2392 chars
#     Level 5: level5_final_report ...
#       Response: 3995 chars
#   [DONE]  Burglary_Burglary037_x264  (98/812)
#
#   [START] Burglary_Burglary040_x264
#   Loading 190 frames (ALL) for Burglary040_x264 ...
#   Loaded 190/190 frames OK
#
#   [Least-to-Most] Burglary040_x264 | 190 frames ...
#     Level 1: Basic visual elements | 10 batches ...
#       Response: 2070 chars
#   [DONE]  Burglary_Burglary038_x264  (99/812)
#
#   [START] Burglary_Burglary041_x264
#   Loading 60 frames (ALL) for Burglary041_x264 ...
#   Loaded 60/60 frames OK
#
#   [Least-to-Most] Burglary041_x264 | 60 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 4413 chars
#     Level 4: level4_classification ...
#       Response: 3116 chars
#     Level 5: level5_final_report ...
#       Visual summary: 818 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3841 chars
#   [DONE]  Burglary_Burglary032_x264  (100/812)
#
#   [START] Burglary_Burglary042_x264
#   Loading 141 frames (ALL) for Burglary042_x264 ...
#   Loaded 141/141 frames OK
#
#   [Least-to-Most] Burglary042_x264 | 141 frames ...
#     Level 1: Basic visual elements | 8 batches ...
#       Response: 2646 chars
#     Level 3: level3_interactions ...
# [Retry 1/7] HTTP 502. Waiting 6.8s ...
#       Visual summary: 1145 chars
#     Level 2: level2_human_behaviour ...
#       Response: 5039 chars
#     Level 4: level4_classification ...
#       Response: 2814 chars
#     Level 5: level5_final_report ...
#       Response: 4144 chars
#     Level 3: level3_interactions ...
#       Response: 2958 chars
#   [DONE]  Burglary_Burglary041_x264  (101/812)
#
#   [START] Burglary_Burglary043_x264
#   Loading 18 frames (ALL) for Burglary043_x264 ...
#   Loaded 18/18 frames OK
#
#   [Least-to-Most] Burglary043_x264 | 18 frames ...
#     Level 1: Basic visual elements | 1 batches ...
#       Visual summary: 389 chars
#     Level 2: level2_human_behaviour ...
#       Response: 5400 chars
#     Level 4: level4_classification ...
#       Visual summary: 1101 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1713 chars
#     Level 3: level3_interactions ...
#       Response: 3319 chars
#     Level 5: level5_final_report ...
#       Response: 2151 chars
#     Level 4: level4_classification ...
#       Response: 2970 chars
#     Level 3: level3_interactions ...
#       Response: 3615 chars
#   [DONE]  Burglary_Burglary040_x264  (102/812)
#
#   [START] Burglary_Burglary044_x264
#   Loading 229 frames (ALL) for Burglary044_x264 ...
#   Loaded 229/229 frames OK
#
#   [Least-to-Most] Burglary044_x264 | 229 frames ...
#     Level 1: Basic visual elements | 12 batches ...
#       Visual summary: 872 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2173 chars
#     Level 5: level5_final_report ...
#       Response: 2404 chars
#   [DONE]  Burglary_Burglary043_x264  (103/812)
#
#   [START] Burglary_Burglary045_x264
#   Loading 365 frames (ALL) for Burglary045_x264 ...
#   Loaded 365/365 frames OK
#
#   [Least-to-Most] Burglary045_x264 | 365 frames ...
#     Level 1: Basic visual elements | 19 batches ...
#       Response: 4283 chars
#     Level 4: level4_classification ...
#       Response: 2915 chars
#     Level 3: level3_interactions ...
#       Response: 3255 chars
#     Level 5: level5_final_report ...
#       Response: 4243 chars
#     Level 4: level4_classification ...
#       Response: 2872 chars
#   [DONE]  Burglary_Burglary039_x264  (104/812)
#
#   [START] Burglary_Burglary046_x264
#   Loading 76 frames (ALL) for Burglary046_x264 ...
#   Loaded 76/76 frames OK
#
#   [Least-to-Most] Burglary046_x264 | 76 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Response: 3056 chars
#     Level 5: level5_final_report ...
#       Response: 3111 chars
#   [DONE]  Burglary_Burglary042_x264  (105/812)
#
#   [START] Burglary_Burglary047_x264
#   Loading 92 frames (ALL) for Burglary047_x264 ...
#   Loaded 92/92 frames OK
#
#   [Least-to-Most] Burglary047_x264 | 92 frames ...
#     Level 1: Basic visual elements | 5 batches ...
#       Visual summary: 946 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 1287 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2681 chars
#     Level 3: level3_interactions ...
#       Visual summary: 1058 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2990 chars
#     Level 3: level3_interactions ...
#       Response: 3068 chars
#     Level 4: level4_classification ...
#       Response: 3816 chars
#     Level 3: level3_interactions ...
#       Response: 4154 chars
#     Level 4: level4_classification ...
#       Response: 2671 chars
#     Level 5: level5_final_report ...
#       Response: 1940 chars
#     Level 5: level5_final_report ...
#       Response: 3647 chars
#   [DONE]  Burglary_Burglary044_x264  (106/812)
#
#   [START] Burglary_Burglary048_x264
#   Loading 55 frames (ALL) for Burglary048_x264 ...
#   Loaded 55/55 frames OK
#
#   [Least-to-Most] Burglary048_x264 | 55 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 6235 chars
#     Level 4: level4_classification ...
#       Response: 4439 chars
#   [DONE]  Burglary_Burglary046_x264  (107/812)
#
#   [START] Burglary_Burglary049_x264
#   Loading 307 frames (ALL) for Burglary049_x264 ...
#   Loaded 307/307 frames OK
#
#   [Least-to-Most] Burglary049_x264 | 307 frames ...
#     Level 1: Basic visual elements | 16 batches ...
#       Visual summary: 1604 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 796 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3626 chars
#     Level 5: level5_final_report ...
#       Response: 2463 chars
#     Level 3: level3_interactions ...
#       Response: 3511 chars
#     Level 3: level3_interactions ...
#       Response: 3604 chars
#     Level 4: level4_classification ...
#       Response: 5588 chars
#   [DONE]  Burglary_Burglary047_x264  (108/812)
#
#   [START] Burglary_Burglary050_x264
#   Loading 38 frames (ALL) for Burglary050_x264 ...
#   Loaded 38/38 frames OK
#
#   [Least-to-Most] Burglary050_x264 | 38 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 5221 chars
#     Level 4: level4_classification ...
#       Response: 2661 chars
#     Level 5: level5_final_report ...
#       Visual summary: 1043 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3250 chars
#     Level 5: level5_final_report ...
#       Response: 3561 chars
#   [DONE]  Burglary_Burglary048_x264  (109/812)
#
#   [START] Burglary_Burglary051_x264
#   Loading 42 frames (ALL) for Burglary051_x264 ...
#   Loaded 42/42 frames OK
#
#   [Least-to-Most] Burglary051_x264 | 42 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 3313 chars
#     Level 3: level3_interactions ...
#       Response: 4742 chars
#   [DONE]  Burglary_Burglary045_x264  (110/812)
#
#   [START] Burglary_Burglary052_x264
#   Loading 333 frames (ALL) for Burglary052_x264 ...
#   Loaded 333/333 frames OK
#
#   [Least-to-Most] Burglary052_x264 | 333 frames ...
#     Level 1: Basic visual elements | 17 batches ...
#       Response: 3783 chars
#     Level 4: level4_classification ...
#       Visual summary: 906 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2824 chars
#     Level 5: level5_final_report ...
#       Response: 3116 chars
#   [DONE]  Burglary_Burglary050_x264  (111/812)
#
#   [START] Burglary_Burglary053_x264
#   Loading 109 frames (ALL) for Burglary053_x264 ...
#       Visual summary: 1224 chars
#     Level 2: level2_human_behaviour ...
#   Loaded 109/109 frames OK
#
#   [Least-to-Most] Burglary053_x264 | 109 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#       Response: 2843 chars
#     Level 3: level3_interactions ...
#       Response: 4809 chars
#     Level 3: level3_interactions ...
#       Response: 4392 chars
#     Level 4: level4_classification ...
#       Visual summary: 685 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3108 chars
#     Level 5: level5_final_report ...
#       Response: 2455 chars
#   [DONE]  Burglary_Burglary051_x264  (112/812)
#
#   [START] Burglary_Burglary054_x264
#   Loading 15 frames (ALL) for Burglary054_x264 ...
#   Loaded 15/15 frames OK
#
#   [Least-to-Most] Burglary054_x264 | 15 frames ...
#     Level 1: Basic visual elements | 1 batches ...
#       Response: 3607 chars
#     Level 3: level3_interactions ...
#       Response: 6372 chars
#     Level 4: level4_classification ...
#       Visual summary: 466 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 832 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1855 chars
#     Level 3: level3_interactions ...
#       Response: 3805 chars
#     Level 5: level5_final_report ...
#       Response: 5973 chars
#     Level 4: level4_classification ...
#       Response: 2693 chars
#     Level 4: level4_classification ...
#       Response: 3608 chars
#     Level 3: level3_interactions ...
#       Response: 2464 chars
#     Level 5: level5_final_report ...
#       Response: 2362 chars
#     Level 5: level5_final_report ...
#       Response: 5313 chars
#   [DONE]  Burglary_Burglary049_x264  (113/812)
#
#   [START] Burglary_Burglary055_x264
#   Loading 94 frames (ALL) for Burglary055_x264 ...
#   Loaded 94/94 frames OK
#
#   [Least-to-Most] Burglary055_x264 | 94 frames ...
#     Level 1: Basic visual elements | 5 batches ...
#       Response: 2621 chars
#   [DONE]  Burglary_Burglary053_x264  (114/812)
#
#   [START] Burglary_Burglary056_x264
#   Loading 47 frames (ALL) for Burglary056_x264 ...
#   Loaded 47/47 frames OK
#
#   [Least-to-Most] Burglary056_x264 | 47 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 2339 chars
#   [DONE]  Burglary_Burglary054_x264  (115/812)
#
#   [START] Burglary_Burglary057_x264
#   Loading 185 frames (ALL) for Burglary057_x264 ...
#   Loaded 185/185 frames OK
#
#   [Least-to-Most] Burglary057_x264 | 185 frames ...
#     Level 1: Basic visual elements | 10 batches ...
#       Response: 5141 chars
#     Level 4: level4_classification ...
#       Response: 3084 chars
#     Level 5: level5_final_report ...
#       Visual summary: 652 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 795 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2497 chars
#     Level 3: level3_interactions ...
#       Response: 2417 chars
#     Level 3: level3_interactions ...
#       Response: 3800 chars
#   [DONE]  Burglary_Burglary052_x264  (116/812)
#
#   [START] Burglary_Burglary058_x264
#   Loading 381 frames (ALL) for Burglary058_x264 ...
#   Loaded 381/381 frames OK
#
#   [Least-to-Most] Burglary058_x264 | 381 frames ...
#     Level 1: Basic visual elements | 20 batches ...
#       Response: 2702 chars
#     Level 4: level4_classification ...
#       Response: 3984 chars
#     Level 4: level4_classification ...
#       Response: 2538 chars
#     Level 5: level5_final_report ...
#       Response: 3073 chars
#     Level 5: level5_final_report ...
#       Visual summary: 1080 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3616 chars
#   [DONE]  Burglary_Burglary055_x264  (117/812)
#
#   [START] Burglary_Burglary059_x264
#   Loading 15 frames (ALL) for Burglary059_x264 ...
#   Loaded 15/15 frames OK
#
#   [Least-to-Most] Burglary059_x264 | 15 frames ...
#     Level 1: Basic visual elements | 1 batches ...
#       Response: 3000 chars
#   [DONE]  Burglary_Burglary056_x264  (118/812)
#
#   [START] Burglary_Burglary060_x264
#   Loading 26 frames (ALL) for Burglary060_x264 ...
#   Loaded 26/26 frames OK
#
#   [Least-to-Most] Burglary060_x264 | 26 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 3253 chars
#     Level 3: level3_interactions ...
#       Visual summary: 445 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 510 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1824 chars
#     Level 3: level3_interactions ...
#       Response: 1594 chars
#     Level 3: level3_interactions ...
#       Response: 5187 chars
#     Level 4: level4_classification ...
#       Response: 1919 chars
#     Level 4: level4_classification ...
#       Response: 2298 chars
#     Level 4: level4_classification ...
#       Response: 2089 chars
#     Level 5: level5_final_report ...
#       Response: 2174 chars
#     Level 5: level5_final_report ...
#       Response: 2942 chars
#     Level 5: level5_final_report ...
#       Response: 2443 chars
#   [DONE]  Burglary_Burglary059_x264  (119/812)
#
#   [START] Burglary_Burglary061_x264
#   Loading 300 frames (ALL) for Burglary061_x264 ...
#   Loaded 300/300 frames OK
#
#   [Least-to-Most] Burglary061_x264 | 300 frames ...
#     Level 1: Basic visual elements | 15 batches ...
#       Response: 2016 chars
#   [DONE]  Burglary_Burglary060_x264  (120/812)
#
#   [START] Burglary_Burglary062_x264
#   Loading 375 frames (ALL) for Burglary062_x264 ...
#   Loaded 375/375 frames OK
#
#   [Least-to-Most] Burglary062_x264 | 375 frames ...
#     Level 1: Basic visual elements | 19 batches ...
#       Response: 5092 chars
#   [DONE]  Burglary_Burglary057_x264  (121/812)
#
#   [START] Burglary_Burglary063_x264
#   Loading 142 frames (ALL) for Burglary063_x264 ...
#   Loaded 142/142 frames OK
#
#   [Least-to-Most] Burglary063_x264 | 142 frames ...
#     Level 1: Basic visual elements | 8 batches ...
#       Visual summary: 1551 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 1013 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3769 chars
#     Level 3: level3_interactions ...
#       Response: 2331 chars
#     Level 3: level3_interactions ...
#       Response: 2873 chars
#     Level 4: level4_classification ...
#       Response: 5280 chars
#     Level 4: level4_classification ...
#       Visual summary: 1176 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2255 chars
#     Level 5: level5_final_report ...
#       Response: 3135 chars
#     Level 5: level5_final_report ...
#       Response: 2743 chars
#   [DONE]  Burglary_Burglary063_x264  (122/812)
#
#   [START] Burglary_Burglary064_x264
#   Loading 1621 frames (ALL) for Burglary064_x264 ...
#   Loaded 1621/1621 frames OK
#
#   [Least-to-Most] Burglary064_x264 | 1621 frames ...
#     Level 1: Basic visual elements | 82 batches ...
#       Response: 3559 chars
#     Level 3: level3_interactions ...
#       Response: 4954 chars
#     Level 4: level4_classification ...
#       Response: 5694 chars
#   [DONE]  Burglary_Burglary058_x264  (123/812)
#
#   [START] Burglary_Burglary065_x264
#   Loading 312 frames (ALL) for Burglary065_x264 ...
#   Loaded 312/312 frames OK
#
#   [Least-to-Most] Burglary065_x264 | 312 frames ...
#     Level 1: Basic visual elements | 16 batches ...
#       Response: 2778 chars
#     Level 5: level5_final_report ...
#       Visual summary: 1091 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3392 chars
#   [DONE]  Burglary_Burglary061_x264  (124/812)
#
#   [START] Burglary_Burglary066_x264
#   Loading 74 frames (ALL) for Burglary066_x264 ...
#   Loaded 74/74 frames OK
#
#   [Least-to-Most] Burglary066_x264 | 74 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Response: 3781 chars
#     Level 3: level3_interactions ...
#       Visual summary: 681 chars
#     Level 2: level2_human_behaviour ...
#       Response: 5026 chars
#     Level 4: level4_classification ...
#       Response: 1797 chars
#     Level 3: level3_interactions ...
#       Response: 2297 chars
#     Level 4: level4_classification ...
#       Response: 3469 chars
#     Level 5: level5_final_report ...
#       Response: 2028 chars
#     Level 5: level5_final_report ...
#       Response: 4485 chars
#   [DONE]  Burglary_Burglary062_x264  (125/812)
#
#   [START] Burglary_Burglary067_x264
#   Loading 44 frames (ALL) for Burglary067_x264 ...
#   Loaded 44/44 frames OK
#
#   [Least-to-Most] Burglary067_x264 | 44 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 2607 chars
#   [DONE]  Burglary_Burglary066_x264  (126/812)
#
#   [START] Burglary_Burglary068_x264
#   Loading 22 frames (ALL) for Burglary068_x264 ...
#   Loaded 22/22 frames OK
#
#   [Least-to-Most] Burglary068_x264 | 22 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Visual summary: 588 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 1021 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 581 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1935 chars
#     Level 3: level3_interactions ...
#       Response: 2302 chars
#     Level 3: level3_interactions ...
#       Response: 3422 chars
#     Level 3: level3_interactions ...
#       Response: 3304 chars
#     Level 4: level4_classification ...
#       Response: 2761 chars
#     Level 4: level4_classification ...
#       Response: 2058 chars
#     Level 5: level5_final_report ...
#       Response: 4376 chars
#     Level 4: level4_classification ...
#       Response: 2291 chars
#     Level 5: level5_final_report ...
#       Response: 2760 chars
#   [DONE]  Burglary_Burglary068_x264  (127/812)
#
#   [START] Burglary_Burglary069_x264
#   Loading 70 frames (ALL) for Burglary069_x264 ...
#   Loaded 70/70 frames OK
#
#   [Least-to-Most] Burglary069_x264 | 70 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Response: 2608 chars
#   [DONE]  Burglary_Burglary067_x264  (128/812)
#
#   [START] Burglary_Burglary070_x264
#   Loading 27 frames (ALL) for Burglary070_x264 ...
# ...
#
#   [START] Vandalism_Vandalism025_x264
#   Loading 143 frames (ALL) for Vandalism025_x264 ...
#   Loaded 143/143 frames OK
#
#   [Least-to-Most] Vandalism025_x264 | 143 frames ...
#     Level 1: Basic visual elements | 8 batches ...
#       Visual summary: 721 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 1898 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2513 chars
#     Level 3: level3_interactions ...
#       Response: 3141 chars
#     Level 4: level4_classification ...
#       Response: 5042 chars
#     Level 3: level3_interactions ...
#       Response: 2242 chars
#     Level 5: level5_final_report ...
#       Response: 2416 chars
#       Visual summary: 929 chars
#     Level 2: level2_human_behaviour ...
#   [DONE]  Vandalism_Vandalism024_x264  (784/812)
#
#   [START] Vandalism_Vandalism026_x264
#   Loading 32 frames (ALL) for Vandalism026_x264 ...
#   Loaded 32/32 frames OK
#
#   [Least-to-Most] Vandalism026_x264 | 32 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 1886 chars
#     Level 3: level3_interactions ...
#       Response: 5994 chars
#     Level 4: level4_classification ...
#       Visual summary: 775 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2083 chars
#     Level 4: level4_classification ...
#       Visual summary: 1341 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2102 chars
#     Level 3: level3_interactions ...
#       Response: 3255 chars
#     Level 5: level5_final_report ...
#       Response: 2324 chars
#     Level 5: level5_final_report ...
#       Response: 2503 chars
#     Level 4: level4_classification ...
#       Response: 3414 chars
#     Level 3: level3_interactions ...
#       Response: 2603 chars
#   [DONE]  Vandalism_Vandalism023_x264  (785/812)
#
#   [START] Vandalism_Vandalism027_x264
#   Loading 23 frames (ALL) for Vandalism027_x264 ...
#   Loaded 23/23 frames OK
#
#   [Least-to-Most] Vandalism027_x264 | 23 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 3996 chars
#   [DONE]  Vandalism_Vandalism022_x264  (786/812)
#
#   [START] Vandalism_Vandalism028_x264
#   Loading 150 frames (ALL) for Vandalism028_x264 ...
#   Loaded 150/150 frames OK
#
#   [Least-to-Most] Vandalism028_x264 | 150 frames ...
#     Level 1: Basic visual elements | 8 batches ...
#       Response: 2064 chars
#     Level 5: level5_final_report ...
#       Response: 4594 chars
#     Level 4: level4_classification ...
#       Visual summary: 905 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2842 chars
#   [DONE]  Vandalism_Vandalism026_x264  (787/812)
#
#   [START] Vandalism_Vandalism029_x264
#   Loading 15 frames (ALL) for Vandalism029_x264 ...
#   Loaded 15/15 frames OK
#
#   [Least-to-Most] Vandalism029_x264 | 15 frames ...
#     Level 1: Basic visual elements | 1 batches ...
#       Response: 1515 chars
#     Level 3: level3_interactions ...
#       Response: 2777 chars
#     Level 5: level5_final_report ...
#       Visual summary: 649 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2509 chars
#     Level 4: level4_classification ...
#       Response: 3119 chars
#   [DONE]  Vandalism_Vandalism025_x264  (788/812)
#
#   [START] Vandalism_Vandalism030_x264
#   Loading 48 frames (ALL) for Vandalism030_x264 ...
#   Loaded 48/48 frames OK
#
#   [Least-to-Most] Vandalism030_x264 | 48 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 2315 chars
#     Level 5: level5_final_report ...
#       Visual summary: 777 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3271 chars
#     Level 3: level3_interactions ...
#       Response: 2698 chars
#   [DONE]  Vandalism_Vandalism027_x264  (789/812)
#
#   [START] Vandalism_Vandalism031_x264
#   Loading 60 frames (ALL) for Vandalism031_x264 ...
#   Loaded 60/60 frames OK
#
#   [Least-to-Most] Vandalism031_x264 | 60 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Response: 2695 chars
#     Level 3: level3_interactions ...
#       Visual summary: 841 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2146 chars
#     Level 3: level3_interactions ...
#       Response: 2793 chars
#     Level 4: level4_classification ...
#       Response: 6173 chars
#     Level 4: level4_classification ...
#       Visual summary: 829 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2084 chars
#     Level 5: level5_final_report ...
#       Response: 3566 chars
#     Level 4: level4_classification ...
#       Response: 3532 chars
#     Level 5: level5_final_report ...
#       Response: 2304 chars
#     Level 3: level3_interactions ...
#       Response: 2804 chars
#   [DONE]  Vandalism_Vandalism029_x264  (790/812)
#
#   [START] Vandalism_Vandalism032_x264
#   Loading 22 frames (ALL) for Vandalism032_x264 ...
#   Loaded 22/22 frames OK
#
#   [Least-to-Most] Vandalism032_x264 | 22 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2397 chars
#     Level 5: level5_final_report ...
#       Response: 2884 chars
#   [DONE]  Vandalism_Vandalism028_x264  (791/812)
#
#   [START] Vandalism_Vandalism033_x264
#   Loading 76 frames (ALL) for Vandalism033_x264 ...
#   Loaded 76/76 frames OK
#
#   [Least-to-Most] Vandalism033_x264 | 76 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Response: 2837 chars
#     Level 4: level4_classification ...
#       Response: 2183 chars
#   [DONE]  Vandalism_Vandalism030_x264  (792/812)
#
#   [START] Vandalism_Vandalism034_x264
#   Loading 59 frames (ALL) for Vandalism034_x264 ...
#   Loaded 59/59 frames OK
#
#   [Least-to-Most] Vandalism034_x264 | 59 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Visual summary: 591 chars
#     Level 2: level2_human_behaviour ...
#       Response: 1788 chars
#     Level 3: level3_interactions ...
#       Response: 2781 chars
#     Level 5: level5_final_report ...
#       Visual summary: 632 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2566 chars
#     Level 4: level4_classification ...
#       Response: 3672 chars
#   [DONE]  Vandalism_Vandalism031_x264  (793/812)
#
#   [START] Vandalism_Vandalism035_x264
#   Loading 40 frames (ALL) for Vandalism035_x264 ...
#   Loaded 40/40 frames OK
#
#   [Least-to-Most] Vandalism035_x264 | 40 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2094 chars
#     Level 5: level5_final_report ...
#       Response: 2892 chars
#     Level 3: level3_interactions ...
#       Visual summary: 1154 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2281 chars
#   [DONE]  Vandalism_Vandalism032_x264  (794/812)
#
#   [START] Vandalism_Vandalism036_x264
#   Loading 48 frames (ALL) for Vandalism036_x264 ...
#   Loaded 48/48 frames OK
#
#   [Least-to-Most] Vandalism036_x264 | 48 frames ...
#     Level 1: Basic visual elements | 3 batches ...
#       Visual summary: 839 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3940 chars
#     Level 4: level4_classification ...
#       Response: 3650 chars
#     Level 3: level3_interactions ...
#       Response: 2063 chars
#     Level 3: level3_interactions ...
#       Response: 3137 chars
#     Level 5: level5_final_report ...
#       Visual summary: 884 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3124 chars
#     Level 4: level4_classification ...
#       Response: 4452 chars
#     Level 4: level4_classification ...
#       Response: 3700 chars
#   [DONE]  Vandalism_Vandalism034_x264  (795/812)
#
#   [START] Vandalism_Vandalism037_x264
#   Loading 101 frames (ALL) for Vandalism037_x264 ...
#   Loaded 101/101 frames OK
#
#   [Least-to-Most] Vandalism037_x264 | 101 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#       Response: 2924 chars
#     Level 3: level3_interactions ...
#       Response: 2371 chars
#     Level 5: level5_final_report ...
#       Response: 3361 chars
#     Level 5: level5_final_report ...
#       Response: 2702 chars
#   [DONE]  Vandalism_Vandalism035_x264  (796/812)
#
#   [START] Vandalism_Vandalism038_x264
#   Loading 94 frames (ALL) for Vandalism038_x264 ...
#   Loaded 94/94 frames OK
#
#   [Least-to-Most] Vandalism038_x264 | 94 frames ...
#     Level 1: Basic visual elements | 5 batches ...
#       Response: 3841 chars
#     Level 4: level4_classification ...
#       Response: 3697 chars
#   [DONE]  Vandalism_Vandalism033_x264  (797/812)
#
#   [START] Vandalism_Vandalism039_x264
#   Loading 30 frames (ALL) for Vandalism039_x264 ...
#   Loaded 30/30 frames OK
#
#   [Least-to-Most] Vandalism039_x264 | 30 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 2550 chars
#     Level 5: level5_final_report ...
#       Visual summary: 1023 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 642 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3943 chars
#   [DONE]  Vandalism_Vandalism036_x264  (798/812)
#
#   [START] Vandalism_Vandalism040_x264
#   Loading 35 frames (ALL) for Vandalism040_x264 ...
#   Loaded 35/35 frames OK
#
#   [Least-to-Most] Vandalism040_x264 | 35 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Visual summary: 839 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2493 chars
#     Level 3: level3_interactions ...
#       Response: 2774 chars
#     Level 3: level3_interactions ...
#       Visual summary: 758 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3628 chars
#     Level 3: level3_interactions ...
#       Response: 3161 chars
#     Level 4: level4_classification ...
#       Response: 3750 chars
#     Level 4: level4_classification ...
#       Response: 2281 chars
#     Level 5: level5_final_report ...
#       Response: 3554 chars
#     Level 3: level3_interactions ...
#       Response: 3149 chars
#     Level 5: level5_final_report ...
#       Response: 4601 chars
#     Level 4: level4_classification ...
#       Response: 2601 chars
#   [DONE]  Vandalism_Vandalism037_x264  (799/812)
#
#   [START] Vandalism_Vandalism041_x264
#   Loading 162 frames (ALL) for Vandalism041_x264 ...
#   Loaded 162/162 frames OK
#
#   [Least-to-Most] Vandalism041_x264 | 162 frames ...
#     Level 1: Basic visual elements | 9 batches ...
#       Response: 3598 chars
#   [DONE]  Vandalism_Vandalism039_x264  (800/812)
#
#   [START] Vandalism_Vandalism042_x264
#   Loading 120 frames (ALL) for Vandalism042_x264 ...
#   Loaded 120/120 frames OK
#
#   [Least-to-Most] Vandalism042_x264 | 120 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#       Response: 2952 chars
#     Level 5: level5_final_report ...
#       Response: 5185 chars
#     Level 4: level4_classification ...
#       Response: 3770 chars
#   [DONE]  Vandalism_Vandalism038_x264  (801/812)
#
#   [START] Vandalism_Vandalism043_x264
#   Loading 108 frames (ALL) for Vandalism043_x264 ...
#   Loaded 108/108 frames OK
#
#   [Least-to-Most] Vandalism043_x264 | 108 frames ...
#     Level 1: Basic visual elements | 6 batches ...
#       Response: 2904 chars
#     Level 5: level5_final_report ...
#       Response: 2587 chars
#   [DONE]  Vandalism_Vandalism040_x264  (802/812)
#
#   [START] Vandalism_Vandalism044_x264
#   Loading 154 frames (ALL) for Vandalism044_x264 ...
#   Loaded 154/154 frames OK
#
#   [Least-to-Most] Vandalism044_x264 | 154 frames ...
#     Level 1: Basic visual elements | 8 batches ...
#       Visual summary: 1085 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 1187 chars
#     Level 2: level2_human_behaviour ...
#       Response: 3845 chars
#     Level 3: level3_interactions ...
#       Response: 3752 chars
#     Level 3: level3_interactions ...
#       Response: 5516 chars
#     Level 4: level4_classification ...
#       Visual summary: 900 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 1004 chars
#     Level 2: level2_human_behaviour ...
#       Response: 4821 chars
#     Level 4: level4_classification ...
#       Response: 3262 chars
#     Level 5: level5_final_report ...
#       Response: 2685 chars
#     Level 3: level3_interactions ...
#       Response: 2177 chars
#     Level 3: level3_interactions ...
#       Response: 3251 chars
#     Level 5: level5_final_report ...
#       Response: 3916 chars
#     Level 4: level4_classification ...
#       Response: 3994 chars
#   [DONE]  Vandalism_Vandalism042_x264  (803/812)
#
#   [START] Vandalism_Vandalism045_x264
#   Loading 145 frames (ALL) for Vandalism045_x264 ...
#   Loaded 145/145 frames OK
#
#   [Least-to-Most] Vandalism045_x264 | 145 frames ...
#     Level 1: Basic visual elements | 8 batches ...
#       Response: 4061 chars
#     Level 4: level4_classification ...
#       Response: 3366 chars
#   [DONE]  Vandalism_Vandalism043_x264  (804/812)
#
#   [START] Vandalism_Vandalism046_x264
#   Loading 70 frames (ALL) for Vandalism046_x264 ...
#   Loaded 70/70 frames OK
#
#   [Least-to-Most] Vandalism046_x264 | 70 frames ...
#     Level 1: Basic visual elements | 4 batches ...
#       Response: 3091 chars
#     Level 5: level5_final_report ...
#       Response: 2359 chars
#     Level 5: level5_final_report ...
#       Response: 3886 chars
#   [DONE]  Vandalism_Vandalism044_x264  (805/812)
#
#   [START] Vandalism_Vandalism047_x264
#   Loading 83 frames (ALL) for Vandalism047_x264 ...
#   Loaded 83/83 frames OK
#
#   [Least-to-Most] Vandalism047_x264 | 83 frames ...
#     Level 1: Basic visual elements | 5 batches ...
#       Response: 3206 chars
#   [DONE]  Vandalism_Vandalism041_x264  (806/812)
#
#   [START] Vandalism_Vandalism048_x264
#   Loading 239 frames (ALL) for Vandalism048_x264 ...
#   Loaded 239/239 frames OK
#
#   [Least-to-Most] Vandalism048_x264 | 239 frames ...
#     Level 1: Basic visual elements | 12 batches ...
#       Visual summary: 764 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 841 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2144 chars
#     Level 3: level3_interactions ...
#       Visual summary: 654 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2477 chars
#     Level 4: level4_classification ...
#       Response: 2917 chars
#     Level 3: level3_interactions ...
#       Response: 2052 chars
#     Level 3: level3_interactions ...
#       Response: 3101 chars
#     Level 5: level5_final_report ...
#       Response: 4042 chars
#     Level 4: level4_classification ...
#       Response: 2292 chars
#     Level 4: level4_classification ...
#       Response: 2373 chars
#   [DONE]  Vandalism_Vandalism046_x264  (807/812)
#
#   [START] Vandalism_Vandalism049_x264
#   Loading 267 frames (ALL) for Vandalism049_x264 ...
#   Loaded 267/267 frames OK
#
#   [Least-to-Most] Vandalism049_x264 | 267 frames ...
#     Level 1: Basic visual elements | 14 batches ...
#       Response: 2077 chars
#     Level 5: level5_final_report ...
#       Response: 2891 chars
#     Level 5: level5_final_report ...
#       Response: 2149 chars
#   [DONE]  Vandalism_Vandalism047_x264  (808/812)
#
#   [START] Vandalism_Vandalism050_x264
#   Loading 30 frames (ALL) for Vandalism050_x264 ...
#   Loaded 30/30 frames OK
#
#   [Least-to-Most] Vandalism050_x264 | 30 frames ...
#     Level 1: Basic visual elements | 2 batches ...
#       Response: 3475 chars
#   [DONE]  Vandalism_Vandalism045_x264  (809/812)
#       Visual summary: 554 chars
#     Level 2: level2_human_behaviour ...
#       Visual summary: 1225 chars
#     Level 2: level2_human_behaviour ...
#       Response: 2188 chars
#     Level 3: level3_interactions ...
#       Response: 3457 chars
#     Level 3: level3_interactions ...
#       Response: 3881 chars
#     Level 4: level4_classification ...
#       Response: 2300 chars
#     Level 5: level5_final_report ...
#       Response: 4628 chars
#     Level 4: level4_classification ...
#       Response: 2536 chars
#   [DONE]  Vandalism_Vandalism050_x264  (810/812)
#       Response: 3615 chars
#     Level 5: level5_final_report ...
#       Response: 3563 chars
#   [DONE]  Vandalism_Vandalism048_x264  (811/812)
#       Visual summary: 1445 chars
#     Level 2: level2_human_behaviour ...
#       Response: 4067 chars
#     Level 3: level3_interactions ...
#       Response: 5540 chars
#     Level 4: level4_classification ...
#       Response: 3208 chars
#     Level 5: level5_final_report ...
#       Response: 3779 chars
#   [DONE]  Vandalism_Vandalism049_x264  (812/812)
#
# Done. Summary -> C:\Opeyemi\PROMPTS\RESULTS\GPT\LEAST-TO-MOST\ltm_summary_20260429_024003.json
#   Processed: 812 | Skipped: 0
#
# ==================================================
# LEAST-TO-MOST PROMPTING COMPLETE!
# Videos processed: 812
# ==================================================
